# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import datetime as datetime
import requests
import ds100_utils
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Getting the Data
# We first pulled all the crime data from the City of Berkeley public dataset.

# %%
calls_url = 'https://data.cityofberkeley.info/api/views/k2nh-s5h5/rows.csv?accessType=DOWNLOAD'
calls_file = ds100_utils.fetch_and_cache(calls_url, 'calls.csv')
calls = pd.read_csv(calls_file, warn_bad_lines=True)
calls.head()
# Out:
# Using cached version that was downloaded (UTC): Sun Oct 27 00:04:32 2019
#      CASENO            OFFENSE                 EVENTDT EVENTTM  \
# 0  19045459  DOMESTIC VIOLENCE  08/16/2019 12:00:00 AM   14:40
# 1  19091565      BURGLARY AUTO  08/03/2019 12:00:00 AM   21:45
# 2  19059951        DISTURBANCE  10/22/2019 12:00:00 AM   12:06
# 3  19091397     IDENTITY THEFT  06/20/2019 12:00:00 AM   12:45
# 4  19026262            ROBBERY  05/13/2019 12:00:00 AM   18:44
#
#              CVLEGEND  CVDOW                InDbDate  \
# 0      FAMILY OFFENSE      5  10/26/2019 07:01:07 AM
# 1  BURGLARY - VEHICLE      6  10/26/2019 07:01:07 AM
# 2  DISORDERLY CONDUCT      2  10/26/2019 07:01:08 AM
# 3               FRAUD      4  10/26/2019 07:01:06 AM
# 4             ROBBERY      1  10/26/2019 07:01:09 AM
#
#                               Block_Location                      BLKADDR  \
# 0     FRONTAGE &UNIVERSITY AVE\nBerkeley, CA     FRONTAGE &UNIVERSITY AVE
# 1                    CENTER ST\nBerkeley, CA                    CENTER ST
# 2               2950 DURANT ST\nBerkeley, CA               2950 DURANT ST
# 3                  PO BOX 5884\nBerkeley, CA                  PO BOX 5884
# 4  CALIFORNIA STREET & 62ND ST\nBerkeley, CA  CALIFORNIA STREET & 62ND ST
#
#        City State
# 0  Berkeley    CA
# 1  Berkeley    CA
# 2  Berkeley    CA
# 3  Berkeley    CA
# 4  Berkeley    CA

# %% [markdown]
# How many records did we get?

# %%
len(calls)
# Out:
# 4979

# %% [markdown]
# ### Preliminary observations on the data?

# %% [markdown]
# 1. `EVENTDT` -- Contains the incorrect time
# 1. `EVENTTM` -- Contains the time in 24 hour format (What timezone?)
# 1. `CVDOW` -- Encodes the day of the week (see data documentation).
# 1. `InDbDate` -- Appears to be correctly formatted and appears pretty consistent in time.
# 1. `Block_Location` -- a multi-line string that contains coordinates.
# 1. `BLKADDR` -- Appears to be the address in `Block Location`.
# 1. `City` and `State` seem redundant given this is supposed to be the city of Berkeley dataset.

# %% [markdown]
# ### Making the polygon
#
# In order to create a constraint on the rideOS API, we need to make a region. So, for each crime event, we create a small box that encompasses the intersection where the crime occurred. The dataframe contains all 4 corners of the crime event.

# %%
calls_lat_lon = (
    calls['Block_Location']
    .str.extract("\((\d+\.\d+)\, (-\d+\.\d+)\)")
)
val = 0.0001
calls_lat_lon.columns = ['Lat', 'Lon']
calls_lat_lon
calls['Lat'] = calls_lat_lon['Lat']
calls['Lon'] = calls_lat_lon['Lon']
calls_dropped =calls.dropna()
calls_dropped['lat++'] = calls_dropped['Lat'].apply(float).round(4)+val
calls_dropped['lon++'] = calls_dropped['Lon'].apply(float).round(4)+val
calls_dropped['lat+-'] = calls_dropped['Lat'].apply(float).round(4)+val
calls_dropped['lon+-'] = calls_dropped['Lon'].apply(float).round(4)-val
calls_dropped['lat--'] = calls_dropped['Lat'].apply(float).round(4)-val
calls_dropped['lon--'] = calls_dropped['Lon'].apply(float).round(4)-val
calls_dropped['lat-+'] = calls_dropped['Lat'].apply(float).round(4)-val
calls_dropped['lon-+'] = calls_dropped['Lon'].apply(float).round(4)+val
calls_dropped['lat++2'] = calls_dropped['Lat'].apply(float).round(4)+val
calls_dropped['lon++2'] = calls_dropped['Lon'].apply(float).round(4)+val

calls_final = calls_dropped.drop('CASENO', axis=1).drop('EVENTTM', axis=1).drop('CVLEGEND', axis=1).drop('CVDOW', axis=1)
calls_square = calls_final.drop('InDbDate', axis=1).drop('Block_Location', axis=1).drop('BLKADDR', axis=1).drop('City', axis=1).drop('State', axis=1).drop('Lat', axis=1).drop('Lon', axis=1)
calls_square= calls_square.reset_index().drop('index', axis=1)

# %%
calls_square.head()
# Out:
#                     OFFENSE                 EVENTDT    lat++     lon++  \
# 0                   ROBBERY  05/30/2019 12:00:00 AM  37.8710 -122.2659
# 1     ASSAULT/BATTERY MISD.  09/22/2019 12:00:00 AM  37.8830 -122.2793
# 2            VEHICLE STOLEN  09/08/2019 12:00:00 AM  37.8597 -122.2972
# 3  THEFT FELONY (OVER $950)  08/13/2019 12:00:00 AM  37.8914 -122.2799
# 4               DISTURBANCE  08/01/2019 12:00:00 AM  37.8738 -122.2685
#
#      lat+-     lon+-    lat--     lon--    lat-+     lon-+   lat++2    lon++2
# 0  37.8710 -122.2661  37.8708 -122.2661  37.8708 -122.2659  37.8710 -122.2659
# 1  37.8830 -122.2795  37.8828 -122.2795  37.8828 -122.2793  37.8830 -122.2793
# 2  37.8597 -122.2974  37.8595 -122.2974  37.8595 -122.2972  37.8597 -122.2972
# 3  37.8914 -122.2801  37.8912 -122.2801  37.8912 -122.2799  37.8914 -122.2799
# 4  37.8738 -122.2687  37.8736 -122.2687  37.8736 -122.2685  37.8738 -122.2685

# %% [markdown]
# ### Filtering the data
#
# In order to not overpopulate the map with crime events, we only took the data from the first three days of July. There were 61 crimes in the span of these three days.

# %%
# filtering the calls_square dataframe based on time
calls_square['EVENTDT'] =  calls_square['EVENTDT'].apply(pd.Timestamp)
calls_square_date_filtered = calls_square[(calls_square['EVENTDT']>pd.Timestamp(year=2019, month=7, day=1)) & (calls_square['EVENTDT']< pd.Timestamp(year=2019, month=7, day=3))]  
calls_square_date_filtered = calls_square_date_filtered.reset_index().drop("index", axis=1)
calls_square_date_filtered.head(5)
# Out:
#                     OFFENSE             EVENTDT    lat++     lon++    lat+-  \
# 0          MISSING JUVENILE 2019-07-01 12:00:00  37.8644 -122.2917  37.8644
# 1  THEFT FELONY (OVER $950) 2019-07-01 12:00:00  37.8700 -122.3005  37.8700
# 2             BURGLARY AUTO 2019-07-02 12:00:00  37.8716 -122.2726  37.8716
# 3             BURGLARY AUTO 2019-07-02 12:00:00  37.8586 -122.2933  37.8586
# 4             BURGLARY AUTO 2019-07-01 12:00:00  37.8802 -122.2974  37.8802
#
#       lon+-    lat--     lon--    lat-+     lon-+   lat++2    lon++2
# 0 -122.2919  37.8642 -122.2919  37.8642 -122.2917  37.8644 -122.2917
# 1 -122.3007  37.8698 -122.3007  37.8698 -122.3005  37.8700 -122.3005
# 2 -122.2728  37.8714 -122.2728  37.8714 -122.2726  37.8716 -122.2726
# 3 -122.2935  37.8584 -122.2935  37.8584 -122.2933  37.8586 -122.2933
# 4 -122.2976  37.8800 -122.2976  37.8800 -122.2974  37.8802 -122.2974

# %%
# DATA USED TO FORMAT BOUNDING BOX FOR API REQUEST
def format_request_data(id_str, plusplus, plusminus, minusminus, minusplus):
    data_template = {
      "constraints": [
        {
          "id": id_str,
          "avoidArea": {
            "positions": [
              {
                "longitude": plusplus[0],
                "latitude": plusplus[1]
              },
              {
                "longitude": plusminus[0],
                "latitude": plusminus[1]
              },
              {
                "longitude": minusminus[0],
                "latitude": minusminus[1]
              },
              {
                "longitude": minusplus[0],
                "latitude": minusplus[1]
              },
              {
                "longitude": plusplus[0],
                "latitude": plusplus[1]
              }
            ]
          }
        }
      ]
    }
    return data_template

# %%
# AUTHORIZATION HEADERS USED IN APPLICATION
headers = {
    "Accept": "application/json",
    "X-Api-Key": "t0vu9A7eqyLtDjLPLa6vdtC2Qhe1ZLYq:Gi-96xXJzAH99imHt09zFmZTSLHo-oLqdQ7UxKxA4nMZvC2X8Tyxrb0sCJ7hLwE2",
    "Content-Type": "application/json"
}

# %%
# USE CONSTRAINT DATA API TO ASSOCIATE WITH OPERATOR LEVEL 
def add_constraint(auth, data):
    response = requests.post('https://api.rideos.ai/constraints/v1/AddOrReplaceConstraints', headers=auth, json=data)
    return response 

# USE RIDE HAIL OPERATIONS TO SET FLEET ROUTING CONSTRAINTS
def set_fleet(auth, fleet_id, id_start, id_end):
    ids = ["demo" + str(i) for i in range(id_start, id_end+1)]
    data = {
      "fleetId": fleet_id,
      "constraints": {
        "blacklistConstraintIds": ids
      }
    }
    response = requests.post('https://api.rideos.ai/ride-hail-operations/v1/SetFleetRoutingConstraints', headers=auth, json=data)
    return response

# %%
# CALLS CURL COMMAND FOR EACH ROW IN THE CRIME DATASET
def curl_commands(crime_df):
    for index, row in crime_df.iterrows():
        data = format_request_data("demo" + str(index), 
                                    (round(row["lon++"], 4), round(row["lat++"], 4)), 
                                    (round(row["lon+-"], 4), round(row["lat+-"], 4)), 
                                    (round(row["lon--"], 4), round(row["lat--"], 4)),
                                    (round(row["lon-+"], 4), round(row["lat-+"], 4)))
        response = add_constraint(headers, data)
        print(response)
    return index

# %%
index = curl_commands(calls_square_date_filtered)
# Out:
# {'constraints': [{'id': 'demo0', 'avoidArea': {'positions': [{'longitude': -122.2917, 'latitude': 37.8644}, {'longitude': -122.2919, 'latitude': 37.8644}, {'longitude': -122.2919, 'latitude': 37.8642}, {'longitude': -122.2917, 'latitude': 37.8642}, {'longitude': -122.2917, 'latitude': 37.8644}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo1', 'avoidArea': {'positions': [{'longitude': -122.3005, 'latitude': 37.87}, {'longitude': -122.3007, 'latitude': 37.87}, {'longitude': -122.3007, 'latitude': 37.8698}, {'longitude': -122.3005, 'latitude': 37.8698}, {'longitude': -122.3005, 'latitude': 37.87}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo2', 'avoidArea': {'positions': [{'longitude': -122.2726, 'latitude': 37.8716}, {'longitude': -122.2728, 'latitude': 37.8716}, {'longitude': -122.2728, 'latitude': 37.8714}, {'longitude': -122.2726, 'latitude': 37.8714}, {'longitude': -122.2726, 'latitude': 37.8716}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo3', 'avoidArea': {'positions': [{'longitude': -122.2933, 'latitude': 37.8586}, {'longitude': -122.2935, 'latitude': 37.8586}, {'longitude': -122.2935, 'latitude': 37.8584}, {'longitude': -122.2933, 'latitude': 37.8584}, {'longitude': -122.2933, 'latitude': 37.8586}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo4', 'avoidArea': {'positions': [{'longitude': -122.2974, 'latitude': 37.8802}, {'longitude': -122.2976, 'latitude': 37.8802}, {'longitude': -122.2976, 'latitude': 37.88}, {'longitude': -122.2974, 'latitude': 37.88}, {'longitude': -122.2974, 'latitude': 37.8802}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo5', 'avoidArea': {'positions': [{'longitude': -122.2936, 'latitude': 37.8703}, {'longitude': -122.2938, 'latitude': 37.8703}, {'longitude': -122.2938, 'latitude': 37.8701}, {'longitude': -122.2936, 'latitude': 37.8701}, {'longitude': -122.2936, 'latitude': 37.8703}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo6', 'avoidArea': {'positions': [{'longitude': -122.2565, 'latitude': 37.8673}, {'longitude': -122.2567, 'latitude': 37.8673}, {'longitude': -122.2567, 'latitude': 37.8671}, {'longitude': -122.2565, 'latitude': 37.8671}, {'longitude': -122.2565, 'latitude': 37.8673}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo7', 'avoidArea': {'positions': [{'longitude': -122.2974, 'latitude': 37.8802}, {'longitude': -122.2976, 'latitude': 37.8802}, {'longitude': -122.2976, 'latitude': 37.88}, {'longitude': -122.2974, 'latitude': 37.88}, {'longitude': -122.2974, 'latitude': 37.8802}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo8', 'avoidArea': {'positions': [{'longitude': -122.2999, 'latitude': 37.8824}, {'longitude': -122.3001, 'latitude': 37.8824}, {'longitude': -122.3001, 'latitude': 37.8822}, {'longitude': -122.2999, 'latitude': 37.8822}, {'longitude': -122.2999, 'latitude': 37.8824}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo9', 'avoidArea': {'positions': [{'longitude': -122.2575, 'latitude': 37.8635}, {'longitude': -122.2577, 'latitude': 37.8635}, {'longitude': -122.2577, 'latitude': 37.8633}, {'longitude': -122.2575, 'latitude': 37.8633}, {'longitude': -122.2575, 'latitude': 37.8635}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo10', 'avoidArea': {'positions': [{'longitude': -122.2914, 'latitude': 37.8813}, {'longitude': -122.2916, 'latitude': 37.8813}, {'longitude': -122.2916, 'latitude': 37.8811}, {'longitude': -122.2914, 'latitude': 37.8811}, {'longitude': -122.2914, 'latitude': 37.8813}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo11', 'avoidArea': {'positions': [{'longitude': -122.259, 'latitude': 37.8688}, {'longitude': -122.2592, 'latitude': 37.8688}, {'longitude': -122.2592, 'latitude': 37.8686}, {'longitude': -122.259, 'latitude': 37.8686}, {'longitude': -122.259, 'latitude': 37.8688}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo12', 'avoidArea': {'positions': [{'longitude': -122.2899, 'latitude': 37.8815}, {'longitude': -122.2901, 'latitude': 37.8815}, {'longitude': -122.2901, 'latitude': 37.8813}, {'longitude': -122.2899, 'latitude': 37.8813}, {'longitude': -122.2899, 'latitude': 37.8815}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo13', 'avoidArea': {'positions': [{'longitude': -122.2919, 'latitude': 37.8692}, {'longitude': -122.2921, 'latitude': 37.8692}, {'longitude': -122.2921, 'latitude': 37.869}, {'longitude': -122.2919, 'latitude': 37.869}, {'longitude': -122.2919, 'latitude': 37.8692}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo14', 'avoidArea': {'positions': [{'longitude': -122.27, 'latitude': 37.8683}, {'longitude': -122.2702, 'latitude': 37.8683}, {'longitude': -122.2702, 'latitude': 37.8681}, {'longitude': -122.27, 'latitude': 37.8681}, {'longitude': -122.27, 'latitude': 37.8683}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo15', 'avoidArea': {'positions': [{'longitude': -122.2586, 'latitude': 37.868}, {'longitude': -122.2588, 'latitude': 37.868}, {'longitude': -122.2588, 'latitude': 37.8678}, {'longitude': -122.2586, 'latitude': 37.8678}, {'longitude': -122.2586, 'latitude': 37.868}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo16', 'avoidArea': {'positions': [{'longitude': -122.2533, 'latitude': 37.8606}, {'longitude': -122.2535, 'latitude': 37.8606}, {'longitude': -122.2535, 'latitude': 37.8604}, {'longitude': -122.2533, 'latitude': 37.8604}, {'longitude': -122.2533, 'latitude': 37.8606}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo17', 'avoidArea': {'positions': [{'longitude': -122.2916, 'latitude': 37.8765}, {'longitude': -122.2918, 'latitude': 37.8765}, {'longitude': -122.2918, 'latitude': 37.8763}, {'longitude': -122.2916, 'latitude': 37.8763}, {'longitude': -122.2916, 'latitude': 37.8765}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo18', 'avoidArea': {'positions': [{'longitude': -122.2501, 'latitude': 37.8694}, {'longitude': -122.2503, 'latitude': 37.8694}, {'longitude': -122.2503, 'latitude': 37.8692}, {'longitude': -122.2501, 'latitude': 37.8692}, {'longitude': -122.2501, 'latitude': 37.8694}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo19', 'avoidArea': {'positions': [{'longitude': -122.2632, 'latitude': 37.8662}, {'longitude': -122.2634, 'latitude': 37.8662}, {'longitude': -122.2634, 'latitude': 37.866}, {'longitude': -122.2632, 'latitude': 37.866}, {'longitude': -122.2632, 'latitude': 37.8662}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo20', 'avoidArea': {'positions': [{'longitude': -122.27, 'latitude': 37.8683}, {'longitude': -122.2702, 'latitude': 37.8683}, {'longitude': -122.2702, 'latitude': 37.8681}, {'longitude': -122.27, 'latitude': 37.8681}, {'longitude': -122.27, 'latitude': 37.8683}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo21', 'avoidArea': {'positions': [{'longitude': -122.2747, 'latitude': 37.8686}, {'longitude': -122.2749, 'latitude': 37.8686}, {'longitude': -122.2749, 'latitude': 37.8684}, {'longitude': -122.2747, 'latitude': 37.8684}, {'longitude': -122.2747, 'latitude': 37.8686}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo22', 'avoidArea': {'positions': [{'longitude': -122.299, 'latitude': 37.8798}, {'longitude': -122.2992, 'latitude': 37.8798}, {'longitude': -122.2992, 'latitude': 37.8796}, {'longitude': -122.299, 'latitude': 37.8796}, {'longitude': -122.299, 'latitude': 37.8798}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo23', 'avoidArea': {'positions': [{'longitude': -122.2727, 'latitude': 37.8858}, {'longitude': -122.2729, 'latitude': 37.8858}, {'longitude': -122.2729, 'latitude': 37.8856}, {'longitude': -122.2727, 'latitude': 37.8856}, {'longitude': -122.2727, 'latitude': 37.8858}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo24', 'avoidArea': {'positions': [{'longitude': -122.2822, 'latitude': 37.8639}, {'longitude': -122.2824, 'latitude': 37.8639}, {'longitude': -122.2824, 'latitude': 37.8637}, {'longitude': -122.2822, 'latitude': 37.8637}, {'longitude': -122.2822, 'latitude': 37.8639}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo25', 'avoidArea': {'positions': [{'longitude': -122.2695, 'latitude': 37.8821}, {'longitude': -122.2697, 'latitude': 37.8821}, {'longitude': -122.2697, 'latitude': 37.8819}, {'longitude': -122.2695, 'latitude': 37.8819}, {'longitude': -122.2695, 'latitude': 37.8821}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo26', 'avoidArea': {'positions': [{'longitude': -122.2606, 'latitude': 37.8649}, {'longitude': -122.2608, 'latitude': 37.8649}, {'longitude': -122.2608, 'latitude': 37.8647}, {'longitude': -122.2606, 'latitude': 37.8647}, {'longitude': -122.2606, 'latitude': 37.8649}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo27', 'avoidArea': {'positions': [{'longitude': -122.2711, 'latitude': 37.8489}, {'longitude': -122.2713, 'latitude': 37.8489}, {'longitude': -122.2713, 'latitude': 37.8487}, {'longitude': -122.2711, 'latitude': 37.8487}, {'longitude': -122.2711, 'latitude': 37.8489}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo28', 'avoidArea': {'positions': [{'longitude': -122.2693, 'latitude': 37.8803}, {'longitude': -122.2695, 'latitude': 37.8803}, {'longitude': -122.2695, 'latitude': 37.8801}, {'longitude': -122.2693, 'latitude': 37.8801}, {'longitude': -122.2693, 'latitude': 37.8803}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo29', 'avoidArea': {'positions': [{'longitude': -122.2677, 'latitude': 37.8673}, {'longitude': -122.2679, 'latitude': 37.8673}, {'longitude': -122.2679, 'latitude': 37.8671}, {'longitude': -122.2677, 'latitude': 37.8671}, {'longitude': -122.2677, 'latitude': 37.8673}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo30', 'avoidArea': {'positions': [{'longitude': -122.2664, 'latitude': 37.9011}, {'longitude': -122.2666, 'latitude': 37.9011}, {'longitude': -122.2666, 'latitude': 37.9009}, {'longitude': -122.2664, 'latitude': 37.9009}, {'longitude': -122.2664, 'latitude': 37.9011}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo31', 'avoidArea': {'positions': [{'longitude': -122.2544, 'latitude': 37.8878}, {'longitude': -122.2546, 'latitude': 37.8878}, {'longitude': -122.2546, 'latitude': 37.8876}, {'longitude': -122.2544, 'latitude': 37.8876}, {'longitude': -122.2544, 'latitude': 37.8878}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo32', 'avoidArea': {'positions': [{'longitude': -122.2693, 'latitude': 37.8803}, {'longitude': -122.2695, 'latitude': 37.8803}, {'longitude': -122.2695, 'latitude': 37.8801}, {'longitude': -122.2693, 'latitude': 37.8801}, {'longitude': -122.2693, 'latitude': 37.8803}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo33', 'avoidArea': {'positions': [{'longitude': -122.2929, 'latitude': 37.857}, {'longitude': -122.2931, 'latitude': 37.857}, {'longitude': -122.2931, 'latitude': 37.8568}, {'longitude': -122.2929, 'latitude': 37.8568}, {'longitude': -122.2929, 'latitude': 37.857}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo34', 'avoidArea': {'positions': [{'longitude': -122.3175, 'latitude': 37.8637}, {'longitude': -122.3177, 'latitude': 37.8637}, {'longitude': -122.3177, 'latitude': 37.8635}, {'longitude': -122.3175, 'latitude': 37.8635}, {'longitude': -122.3175, 'latitude': 37.8637}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo35', 'avoidArea': {'positions': [{'longitude': -122.2925, 'latitude': 37.8703}, {'longitude': -122.2927, 'latitude': 37.8703}, {'longitude': -122.2927, 'latitude': 37.8701}, {'longitude': -122.2925, 'latitude': 37.8701}, {'longitude': -122.2925, 'latitude': 37.8703}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo36', 'avoidArea': {'positions': [{'longitude': -122.2695, 'latitude': 37.8638}, {'longitude': -122.2697, 'latitude': 37.8638}, {'longitude': -122.2697, 'latitude': 37.8636}, {'longitude': -122.2695, 'latitude': 37.8636}, {'longitude': -122.2695, 'latitude': 37.8638}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo37', 'avoidArea': {'positions': [{'longitude': -122.3161, 'latitude': 37.8704}, {'longitude': -122.3163, 'latitude': 37.8704}, {'longitude': -122.3163, 'latitude': 37.8702}, {'longitude': -122.3161, 'latitude': 37.8702}, {'longitude': -122.3161, 'latitude': 37.8704}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo38', 'avoidArea': {'positions': [{'longitude': -122.2705, 'latitude': 37.8707}, {'longitude': -122.2707, 'latitude': 37.8707}, {'longitude': -122.2707, 'latitude': 37.8705}, {'longitude': -122.2705, 'latitude': 37.8705}, {'longitude': -122.2705, 'latitude': 37.8707}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo39', 'avoidArea': {'positions': [{'longitude': -122.2612, 'latitude': 37.8685}, {'longitude': -122.2614, 'latitude': 37.8685}, {'longitude': -122.2614, 'latitude': 37.8683}, {'longitude': -122.2612, 'latitude': 37.8683}, {'longitude': -122.2612, 'latitude': 37.8685}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo40', 'avoidArea': {'positions': [{'longitude': -122.272, 'latitude': 37.8736}, {'longitude': -122.2722, 'latitude': 37.8736}, {'longitude': -122.2722, 'latitude': 37.8734}, {'longitude': -122.272, 'latitude': 37.8734}, {'longitude': -122.272, 'latitude': 37.8736}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo41', 'avoidArea': {'positions': [{'longitude': -122.2708, 'latitude': 37.8505}, {'longitude': -122.271, 'latitude': 37.8505}, {'longitude': -122.271, 'latitude': 37.8503}, {'longitude': -122.2708, 'latitude': 37.8503}, {'longitude': -122.2708, 'latitude': 37.8505}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo42', 'avoidArea': {'positions': [{'longitude': -122.2895, 'latitude': 37.8722}, {'longitude': -122.2897, 'latitude': 37.8722}, {'longitude': -122.2897, 'latitude': 37.872}, {'longitude': -122.2895, 'latitude': 37.872}, {'longitude': -122.2895, 'latitude': 37.8722}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo43', 'avoidArea': {'positions': [{'longitude': -122.2663, 'latitude': 37.8742}, {'longitude': -122.2665, 'latitude': 37.8742}, {'longitude': -122.2665, 'latitude': 37.874}, {'longitude': -122.2663, 'latitude': 37.874}, {'longitude': -122.2663, 'latitude': 37.8742}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo44', 'avoidArea': {'positions': [{'longitude': -122.2682, 'latitude': 37.8713}, {'longitude': -122.2684, 'latitude': 37.8713}, {'longitude': -122.2684, 'latitude': 37.8711}, {'longitude': -122.2682, 'latitude': 37.8711}, {'longitude': -122.2682, 'latitude': 37.8713}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo45', 'avoidArea': {'positions': [{'longitude': -122.2719, 'latitude': 37.8837}, {'longitude': -122.2721, 'latitude': 37.8837}, {'longitude': -122.2721, 'latitude': 37.8835}, {'longitude': -122.2719, 'latitude': 37.8835}, {'longitude': -122.2719, 'latitude': 37.8837}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo46', 'avoidArea': {'positions': [{'longitude': -122.3099, 'latitude': 37.8656}, {'longitude': -122.3101, 'latitude': 37.8656}, {'longitude': -122.3101, 'latitude': 37.8654}, {'longitude': -122.3099, 'latitude': 37.8654}, {'longitude': -122.3099, 'latitude': 37.8656}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo47', 'avoidArea': {'positions': [{'longitude': -122.2662, 'latitude': 37.874}, {'longitude': -122.2664, 'latitude': 37.874}, {'longitude': -122.2664, 'latitude': 37.8738}, {'longitude': -122.2662, 'latitude': 37.8738}, {'longitude': -122.2662, 'latitude': 37.874}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo48', 'avoidArea': {'positions': [{'longitude': -122.2752, 'latitude': 37.8576}, {'longitude': -122.2754, 'latitude': 37.8576}, {'longitude': -122.2754, 'latitude': 37.8574}, {'longitude': -122.2752, 'latitude': 37.8574}, {'longitude': -122.2752, 'latitude': 37.8576}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo49', 'avoidArea': {'positions': [{'longitude': -122.2639, 'latitude': 37.8528}, {'longitude': -122.2641, 'latitude': 37.8528}, {'longitude': -122.2641, 'latitude': 37.8526}, {'longitude': -122.2639, 'latitude': 37.8526}, {'longitude': -122.2639, 'latitude': 37.8528}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo50', 'avoidArea': {'positions': [{'longitude': -122.2614, 'latitude': 37.8575}, {'longitude': -122.2616, 'latitude': 37.8575}, {'longitude': -122.2616, 'latitude': 37.8573}, {'longitude': -122.2614, 'latitude': 37.8573}, {'longitude': -122.2614, 'latitude': 37.8575}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo51', 'avoidArea': {'positions': [{'longitude': -122.2749, 'latitude': 37.8713}, {'longitude': -122.2751, 'latitude': 37.8713}, {'longitude': -122.2751, 'latitude': 37.8711}, {'longitude': -122.2749, 'latitude': 37.8711}, {'longitude': -122.2749, 'latitude': 37.8713}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo52', 'avoidArea': {'positions': [{'longitude': -122.2781, 'latitude': 37.8945}, {'longitude': -122.2783, 'latitude': 37.8945}, {'longitude': -122.2783, 'latitude': 37.8943}, {'longitude': -122.2781, 'latitude': 37.8943}, {'longitude': -122.2781, 'latitude': 37.8945}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo53', 'avoidArea': {'positions': [{'longitude': -122.2842, 'latitude': 37.8702}, {'longitude': -122.2844, 'latitude': 37.8702}, {'longitude': -122.2844, 'latitude': 37.87}, {'longitude': -122.2842, 'latitude': 37.87}, {'longitude': -122.2842, 'latitude': 37.8702}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo54', 'avoidArea': {'positions': [{'longitude': -122.2625, 'latitude': 37.8629}, {'longitude': -122.2627, 'latitude': 37.8629}, {'longitude': -122.2627, 'latitude': 37.8627}, {'longitude': -122.2625, 'latitude': 37.8627}, {'longitude': -122.2625, 'latitude': 37.8629}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo55', 'avoidArea': {'positions': [{'longitude': -122.2696, 'latitude': 37.8837}, {'longitude': -122.2698, 'latitude': 37.8837}, {'longitude': -122.2698, 'latitude': 37.8835}, {'longitude': -122.2696, 'latitude': 37.8835}, {'longitude': -122.2696, 'latitude': 37.8837}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo56', 'avoidArea': {'positions': [{'longitude': -122.3099, 'latitude': 37.8656}, {'longitude': -122.3101, 'latitude': 37.8656}, {'longitude': -122.3101, 'latitude': 37.8654}, {'longitude': -122.3099, 'latitude': 37.8654}, {'longitude': -122.3099, 'latitude': 37.8656}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo57', 'avoidArea': {'positions': [{'longitude': -122.2531, 'latitude': 37.8585}, {'longitude': -122.2533, 'latitude': 37.8585}, {'longitude': -122.2533, 'latitude': 37.8583}, {'longitude': -122.2531, 'latitude': 37.8583}, {'longitude': -122.2531, 'latitude': 37.8585}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo58', 'avoidArea': {'positions': [{'longitude': -122.28, 'latitude': 37.8753}, {'longitude': -122.2802, 'latitude': 37.8753}, {'longitude': -122.2802, 'latitude': 37.8751}, {'longitude': -122.28, 'latitude': 37.8751}, {'longitude': -122.28, 'latitude': 37.8753}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo59', 'avoidArea': {'positions': [{'longitude': -122.259, 'latitude': 37.8688}, {'longitude': -122.2592, 'latitude': 37.8688}, {'longitude': -122.2592, 'latitude': 37.8686}, {'longitude': -122.259, 'latitude': 37.8686}, {'longitude': -122.259, 'latitude': 37.8688}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo60', 'avoidArea': {'positions': [{'longitude': -122.3021, 'latitude': 37.8823}, {'longitude': -122.3023, 'latitude': 37.8823}, {'longitude': -122.3023, 'latitude': 37.8821}, {'longitude': -122.3021, 'latitude': 37.8821}, {'longitude': -122.3021, 'latitude': 37.8823}]}}]}
# <Response [200]>
# {'constraints': [{'id': 'demo61', 'avoidArea': {'positions': [{'longitude': -122.2839, 'latitude': 37.8537}, {'longitude': -122.2841, 'latitude': 37.8537}, {'longitude': -122.2841, 'latitude': 37.8535}, {'longitude': -122.2839, 'latitude': 37.8535}, {'longitude': -122.2839, 'latitude': 37.8537}]}}]}
# <Response [200]>

# %%
FLEET_ID = "0"
START_INDEX = 0 
END_INDEX = index

# %%
fleet_response = set_fleet(headers, "sim_fleet_dee8f8", START_INDEX, END_INDEX)
print(fleet_response)
# Out:
# <Response [200]>
